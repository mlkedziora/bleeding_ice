# %%
import sys
# !{sys.executable} -m pip install numpy tensorflow>=2.10.0 matplotlib scikit-learn opencv-python

# %%
import os

# Establishing the baseline path to ensure relative imports work.
current_dir = os.getcwd()
print(f"Notebook Location: {current_dir}")

# Defining the target project root.
target_path = os.path.join(current_dir, 'CW2-Poster')

# Checking if the target directory exists.
if os.path.exists(target_path):
    os.chdir(target_path)
    print(f"Working directory changed to: {os.getcwd()}")
    print()
    
    # Sanity check
    if os.path.exists('code'):
        print("Found directory")
    else:
        print("Failed to find the 'code' folder.")
        print(f"Contents: {os.listdir(os.getcwd())}")
print()

# Cloning the original implementation to a separate directory to serve as a reference point.
repo_url = "https://github.com/davej23/attention-mechanism-unet.git"
repo_name = "original_paper_code"

if not os.path.exists(repo_name):
    print(f"Cloning: {repo_name}")
    # !git clone {repo_url} {repo_name}
else:
    print("Reference already exists.")
# Out:
# Notebook Location: /home/ec2-user/SageMaker
# Working directory changed to: /home/ec2-user/SageMaker/CW2-Poster
#
# Found directory
#
# Reference already exists.

# %%
# !python code/replicate_amazon.py
# Out:
# 2025-12-09 14:35:18.670798: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-09 14:35:28.070652: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-09 14:35:33.122057: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-09 14:35:33.156966: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python code/nepal_eda.py
# Out:
# Dataset Split Overview
# Training Set:       328 images
# Internal Val Set:   82 images
# External Test Set:  10 images
#
# No filename leakage detected.
# Checking content duplicates in Training Set
# No identical image content found in Training Set.
#
# Analysing Training Data (Red Channel)
# Mean: 180.41 | Std: 86.34
# Analysing External Test Data (Red Channel)
# Mean: 170.55 | Std: 52.21
# Domain Shift Analysis Conclusion.
# Difference in Mean Brightness: 9.86
# Minor shift detected.
#
# Analysing Class Balance for Training Set
# Lake: 13.15% | Background: 86.85%
# Analysing Class Balance for External Test Set
# Lake: 2.72% | Background: 97.28%
#
# /home/ec2-user/SageMaker/CW2-Poster/code/nepal_eda.py:224: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bplot = plt.boxplot(data, labels=['Training Lakes', 'Nepal Lakes'], patch_artist=True)
# ...

# %%
# !python code/adapt_nepal.py
# Out:
# 2025-12-09 15:04:26.764269: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-09 15:04:34.324727: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-09 15:04:38.347657: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-09 15:04:38.385235: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python code/monitor_tsho_rolpa.py
# Out:
# 2025-12-09 15:45:00.408692: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-09 15:45:09.316725: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-09 15:45:14.188531: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-09 15:45:14.221533: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
